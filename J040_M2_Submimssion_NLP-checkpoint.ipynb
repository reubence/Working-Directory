# %%
import pandas as pd
import numpy as np
import nltk
from bs4 import BeautifulSoup

import re
import nltk
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import NMF
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfTransformer,CountVectorizer,TfidfVectorizer
from nltk import word_tokenize
import string 
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.decomposition import nmf
from nltk.corpus import stopwords
from nltk.tokenize import MWETokenizer,word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from nltk.corpus import wordnet
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split as tts,GridSearchCV
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from gensim.models import word2vec

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
url = "https://raw.githubusercontent.com/reubence/IPYNB-Notebooks/master/datasets/Articles.csv"
df_art = pd.read_csv(url, encoding = "utf-8’")

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('german'))
nltk.download('words')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
df_art.head()
# Out:
#    ID_Article  ...                                               Body
# 0           1  ...  <div class="section" id="content-main" itempro...
# 1           2  ...  <div class="diashow" id="objectContent"><meta ...
# 2           3  ...  <div class="section" id="content-main" itempro...
# 3           4  ...  <div class="section" id="content-main" itempro...
# 4           5  ...  <div class="section" id="content-main" itempro...
#
# [5 rows x 5 columns]

# %%
def to_lower(str): # steps... 
                 # 1.  Lowering and removing digits and separating gmail words because we dont want to read nicknames and emails
  text= str.lower() #1
  text = text.translate(text.maketrans('', '', string.digits))
  text = text.translate(text.maketrans('', '', '''!()-[]{};:'"\,<>./?@#$%^&*_~'''))
  str_new = " ".join(re.findall("[a-zA-Z]+", text))
  return str_new

# %%
 def tokenize(str_new):
      # 2. Tokenizing again because the result returns a string.. just to be safe
  tokens = [] #2
  tokens = nltk.word_tokenize(str_new)
  return tokens

# %%
def remove_stop(tokens):
  # 3. Removing stopwords using german corpus... also removinbg punctuations
  removed = [] #3
  stopword = stopwords.words('german') 
  punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
  for w in tokens:
    if (w.lower() not in stopword and w.lower() not in punctuations):
      removed.append(w.lower())
  return removed

# %%
def pos_tag(removed):
           # 4. Pos Tagging for Lemmatizing
  pos = [] #4
  pos.append(nltk.pos_tag(removed))
  return pos

# %%
def lemma(pos):
# 5. Lemmatizing
               
  lem = WordNetLemmatizer() #5
  lemma = []
  for word in pos:
    for w in word:
      pos_value = ""
      if (w[1].startswith('J')):
        pos_value = wordnet.ADJ
      elif (w[1].startswith('V')):
        pos_value = wordnet.VERB
      elif (w[1].startswith('N')):
        pos_value = wordnet.NOUN
      elif (w[1].startswith('R')):
        pos_value = wordnet.ADV 
      else:
        continue
      lemma.append(lem.lemmatize(w[0],pos_value))
  return lemma

# %%
def to_string(lemma): # 6. Return Sentence instead of tokens
  str1 = ' '.join([elem for elem in lemma]) #6
  return (str1)

# %% [markdown]
# # Sklearn Pipeline using Function Transformer

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer

pipeline = make_pipeline(
        FunctionTransformer(to_lower),
        FunctionTransformer(tokenize),
        FunctionTransformer(remove_stop),
        FunctionTransformer(pos_tag),
        FunctionTransformer(lemma),
        FunctionTransformer(to_string),
    )

# %%
#Selecting first 1000 rows only
df_art = df_art.head(1000)
df_art.head()
# Out:
#    ID_Article  ...                                               Body
# 0           1  ...  <div class="section" id="content-main" itempro...
# 1           2  ...  <div class="diashow" id="objectContent"><meta ...
# 2           3  ...  <div class="section" id="content-main" itempro...
# 3           4  ...  <div class="section" id="content-main" itempro...
# 4           5  ...  <div class="section" id="content-main" itempro...
#
# [5 rows x 5 columns]

# %%
df_art["Title-Cleaned"] = df_art["Title"].apply(pipeline.fit_transform)
df_art["Title-Cleaned"]
# Out:
# 0                               newsletter derstandardat
# 1                                     teil derstandardat
# 2                              android app derstandardat
# 3                        erfahrungen linksh nder gemacht
# 4                                            jahr erlebt
#                              ...
# 995                 casinoschef konzern komplett umbauen
# 996                            window steht mobilversion
# 997    aufregung kettens genmassaker wieso neue doom ...
# 998        telekom austria pr ft pilzangaben nsaspionage
# 999    selbstfahrende googleautos ffentlichen stra un...
# Name: Title-Cleaned, Length: 1000, dtype: object

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df_art['Title-Cleaned'])
x = pd.DataFrame(X.toarray(),columns=vectorizer.get_feature_names())

# %%
nmf=NMF(4,random_state=42,alpha=0.1,l1_ratio=0.5,init='nndsvd')
arr=nmf.fit_transform(x)
h = nmf.components_

# %%
def display_topics(H,feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        top_doc_indices = np.argsort( H[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print(documents[doc_index])

# %%
x.apply(display_topics(nmf.components_,vectorizer.get_feature_names(),df_art['Title-Cleaned'],100000,1000))
# Out:
# Topic 0:
# neue wiener ndigt angek gr sp android mpfe ne greifen regeln gemeindewohnungen apple wieso mass sparsamer effect playstation tb speicher andromeda leichter galaxie aufbruch google fl zwei griechenland ge le vorschl eurosondergipfel chtlinge music botaniker wiesen pflanzenarten smarttvsystem tv kan sen tze aufregung paris bringt doom schaffen kettens brutal genmassaker zwergplanet pl erster ukraine ansicht mysteri cere flecken haus blick kommen softwaregeneration feuer ostukraine teurer fronten tschechows gewehr rfte geschichteprojekt burg not zinsflaute steuerbelastungen anleger versuch reifepr ersten bilanz fung streamingdienst ten sollen raketen fordert stoppen selbstmordpanzerattacken arbeitslose ak strategie reisende entt schlichtungsstelle uschte chat orfstruktur livebericht rden feature kollateralfragen realit unobericht gazakrieg sch lle stra startet ere matura schulen spielen fp wahlkampf antifp nde wowspieler podcast ler lehrer benotet regime dishonor neues killer geboren luchse nbrunn tiergarten venezuela car project offroadrennen koopkarriere dorfer nu asyl verteilzentrum kommt golfb versto konvention amtsanma ungsprozess enstrich selbstjustiz neunj schuldspruch anwalt brach arm hriger sozialwohnungen intermezzo vorgereiht neustadt erwartete ende hrige langj regenbogenparade trotzt regenwetter waterloo breguet kongress ubahn areal menschenlos fahrzeugbrand tankstelle fahrerlos video hilfsmittel einheitliche regelung zentralmatura fordern kritisieren wirtschaftskammer tiroler inseratenwahn feministische initiative forschung ngen ablinger warum kritiker gericht genus geoblocking gerhard expr expolitiker geordnetes georg georgien ext
bsverfahren euweiten euweit eustaaten eurosondergipfel explorer explosionen expo fahrerlos familie falschen fallout fall faire faircover fair fahrzeugbrand fahrradunfall facebookcommunity expolitiker facebookchef facebook fabasoft exzentrik extremisten extras extra exstronachmandatare expr finanzer findet garden fstein fronten fritsch friss frischer friedensgespr frieden friaul freundschaftsdienste freunde frequenzauktion frequently fremde freitag freispruch freilandeier freiheit freihandel freigesprochen frei frauenleiche frau fstand guardian fiorentinatrainer ften garantieren gap gang gaminghype gametalk game galaxien galaxie gajeta gabalier gab funkt funkstille fungskommission fung fundb fuchs fu ftsmodell ftsf ftling franz frankreich frankfurt fraglich folgen flugzeugabsturz flughafenstreit flugger flucht fluch flotte flieht fleischkenner fleischfressern fleisch flei flecken flat flassbeck fixiert fischsauce fischotter fischer fisch firmengr folgenreiche folgt follower fortgesetzte fragen fr fp fox foundation fotos foto foru ...
# erfahrungen linksh nder gemacht
# android app derstandardat
# teil derstandardat
# newsletter derstandardat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-688e0c3b7e9b> in <module>()
# ----> 1 x.apply(display_topics(nmf.components_,vectorizer.get_feature_names(),df_art['Title-Cleaned'],100000,1000))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# TypeError: ("'NoneType' object is not callable", 'occurred at index ab')

# %%
LD=LatentDirichletAllocation(n_components=4,random_state=42)
fi=LD.fit_transform(x)
fi
# Out:
# array([[0.08339472, 0.74857397, 0.08399237, 0.08403894],
#        [0.08339472, 0.74857397, 0.08399237, 0.08403894],
#        [0.06450598, 0.80942915, 0.06322398, 0.06284089],
#        ...,
#        [0.90545788, 0.03149606, 0.03176911, 0.03127694],
#        [0.03811158, 0.88814761, 0.03620104, 0.03753977],
#        [0.04183747, 0.04183698, 0.04170439, 0.87462116]])

# %%
def yolo(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
x.apply(yolo(LD,vectorizer,9))
#It's working!
# Out:
# Topic #0:
# neue gro ber fl sch wien macht kurz sterreich
#
# Topic #1:
# ber apple wien verl sterreich eu drei warum gehen
#
# Topic #2:
# fp neue sterreich zwei gr europa sp mehr ck
#
# Topic #3:
# wiener google griechenland gestorben lt fp mehr erneut erh
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-d3ff59cb683f> in <module>()
# ----> 1 x.apply(yolo(LD,vectorizer,9))
#       2 #It's working!
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# TypeError: ("'NoneType' object is not callable", 'occurred at index ab')

# %% [markdown]
# new

# %%
def striphtml(data):
    p = re.compile(r'<.*?>')
    return p.sub('', data)

# %%
df_art["Clean-Body-NO-html"]  = df_art['Body'].apply(striphtml)

# %%
df_art["Clean-Body-NO-html"]
# Out:
# 0      Abonnieren Sie einen unserer Newsletter und la...
# 1      Werden Sie Teil von derStandard.at!10. Dezembe...
# 2      Die Smartphone-App bietet Nachrichten in Echtz...
# 3      Wie sieht Ihr Alltag als Linkshänder aus? Erle...
# 4      Erzählen Sie uns von Ihren Erlebnissen rund um...
#                              ...
# 995    Die Lotterien sollen zu 100 Prozent unter ein ...
# 996    Microsoft-CEO Nadella kündigt "harte Entscheid...
# 997    Hersteller: "Wenn du mit blutigen Games nichts...
# 998    Grüner Abgeordneter hatte von flächendeckendem...
# 999    Zunächst sicherheitshalber noch speziell gesch...
# Name: Clean-Body-NO-html, Length: 1000, dtype: object

# %%
df_art["Body-Cleaned"]=  df_art["Clean-Body-NO-html"].apply(pipeline.fit_transform)
df_art["Body-Cleaned"]
# Out:
# 0      abonnieren unserer newsletter lassen aktuelle ...
# 1      teil derstandardat dezember function popupwinp...
# 2      smartphoneapp bietet nachrichten echtzeit m gl...
# 3      sieht alltag linksh nder erledigen arbeiten re...
# 4      erz hlen erlebnissen rund weltpolitischen umbr...
#                              ...
# 995    lotterien sollen prozent dach konzernchef stos...
# 996    microsoftceo nadella k ndigt harte entscheidun...
# 997    hersteller blutigen game anfangen kannst f r d...
# 998    gr ner abgeordneter fl chendeckendem lauschang...
# 999    zun chst sicherheitshalber speziell geschulte ...
# Name: Body-Cleaned, Length: 1000, dtype: object

# %%
df_art.head()
# Out:
#    ID_Article  ...                                       Body-Cleaned
# 0           1  ...  abonnieren unserer newsletter lassen aktuelle ...
# 1           2  ...  teil derstandardat dezember function popupwinp...
# 2           3  ...  smartphoneapp bietet nachrichten echtzeit m gl...
# 3           4  ...  sieht alltag linksh nder erledigen arbeiten re...
# 4           5  ...  erz hlen erlebnissen rund weltpolitischen umbr...
#
# [5 rows x 8 columns]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df_art['Body-Cleaned'])
x = pd.DataFrame(X.toarray(),columns=vectorizer.get_feature_names())

# %%
model = NMF(n_components=5, init='nndsvd', random_state=0, alpha=0.1, l1_ratio=0.5)
W = model.fit_transform(x)

# %%
H = model.components_

# %%
W

# %%
H

# %%
dfW=pd.DataFrame(W)

# %%
dfW.head()

# %%
def display_topics(H, W, feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print(documents[doc_index])

# %%
x.apply(display_topics(nmf.components_,vectorizer.get_feature_names(),df_art['Body-Cleaned'],100000,1000))
# Out:
# Topic 0:
# teil derstandardat dezember function popupwinpage width height noscroll popup windowopenpage popupwin toolbar nomenubar noscrollbars noscroll resizable yes width width height height leave top popup null popupfocus postingsmit registrierung derstandardat m gliche newsletter interessanten themen abonnieren gewinnspielen teilnehmen vieles mehr direkt registrierung screenshot derstandardatbild registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts var slideshowparameter url ineigenersachewerdensieteilvonderstandardat page template default var slideshowentries new array slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textum registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbei neuregistrierung f llen bitte pflichtfelder best tigungslink emailadresse zugestellt bekommen achten bitte darauf emailadresse korrekt einzugeben passwort frei w hlbar mindestens sechs zeichen bestehen erlaubte zeichen siehe i bitte akzeptieren allgemeinen gesch ftsbedingungen creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbitte berpr fen email klicken link aktivierung benutzeraccounts fall minuten email erhalten sehen bitte email spamordner gelandet creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textmit klick link benutzeraccount aktiviert k passwort anmelden creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textim abschlie enden optionalen schritt k nnen adressdaten eingeben newsletter undoder gratis abo f r standard bestellen sollten fragen bez glich registrierung derstandardat finden antwort faq fall weiterhelfen k nnen gerne forenteam wenden willkommen derstandardat direkt registrierung creditsscreenshot derstandardat stdslideshowinitslideshowparameter slideshowentries
# sieht alltag linksh nder erledigen arbeiten rechts statt linkssie schreiben wischen tinte verschmierte handfl che greifen computermaus greifen leere schneiden verzweifeln rechtsh nderschere nagelschere dosen ffner nde obwohl angebot f r linksh nder vergangenen jahren sukzessive gestiegen sogar eigene gesch fte gibt material f r linksh nder anbieten welt f r rechtsh nder flexibilit t lernen daher m ssen linksh nder oftmals lernen flexibel bestimmten situationen rechte hand haupthand verwenden alltag erleichtert best beispiel beim autofahren schaltet sofern l nder auswandern m chte rechts heute august internationale tag f r linksh nder deswegen sicher communityabteilung derstandardat hohe linksh nderquote vorweisen k nnen freuen ber erlebnisse erledigen arbeiten rechts erfahrungen linksh nder gemacht schon rgern gegenst nde f r rechtsh nder gemacht wurden etwa schule ergangen lehrer darauf eingegangen linksh nder gibt gewisse arbeiten rechts erledigen gegebenheiten erfordern sni derstandardat thema interview weltlinksh ndertag kinder ziemlich alleingelassen
# smartphoneapp bietet nachrichten echtzeit m glichkeit unterwegs postenupdate google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version android app erh ltlich googleplaystore versucht hohen ma onlinenachrichtenerlebnis vollversion gewohnt smartphone bertragen warum androidapp entwicklung app langgehegten wunsch unserer user nachgegangen app pr sentiert speziell f r endger t optimierte version unserer mobilen website zu tzlichen nativen navigationselementen ersten release februar unz hligen aktualisierungen unserer mobilen website fehler app korrigiert bzw etliche einschr nkungen damals aktuellen betriebssystems reagiert geschwindigkeits stabilit tsoptimierungen unterst tzung aktueller betriebssysteme sowie kompletten berarbeitung einbindung unserer communityfunktionen hoffen treuen appbenutzern gew nschten mehrwert geben f r smartphoneuser browserlandschaft wohler f hlen gibt m glichkeit website benutzen httpmobilderstandardat benutze app wesentliche navigationselement befindet dabei rechts unten einmaligem dr cken f hrt sitemap button allerdings l nger gedr ckt erscheint expressnavigation schnell effizient einzelnen channel gelangen aktuellen standort innerhalb inhaltsbaums k nnen jederzeit abfragen dr cken linken unteren button artikelebene sehen unten mitte immer anzahl dazugeh rigen posting dr cken element kommen posting bzw k nnen unterwegs posten brauchen benutzerkennung passwort registrierung vollversion button postingzahl erlaubt aktuelle meldung schnell freunde bekannte weiterzuleiten angeboten mail facebook google twitter hinweise installation f bekomme trotz aktualisierung app fehlermeldung bestimmte funtionen neuen update verf gbar sinda versuchen app ger t entfernen ausf hrung stoppen deinstallieren installieren bitte aktuelle version playstore android ger ten problemen beim aktualisieren kommen nachrichten echtzeit posten amp bewerten w nschen spa aktuellen version unserer android app anregungen gerne form posting email mobilderstandardat entgegengenommen team derstandardat update google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version
# abonnieren unserer newsletter lassen aktuelle nachrichten mail zuschicken derstandardat bietet vielzahl themenbezogener newsletter anunter motto nachrichten echtzeit liefert derstandardat wichtigsten meldungen tages email html textversion derstandardatnewsletter k nnen kostenloses newsletterabonnement bequem abmelden newsletter berblick dmail newsroom spitzenmeldungen newsroomressortsdmail meinung aktuelle kommentare kolumnendmail internationalpolitik topnews ber internationale geschehendmail innenpolitik topnews ber innenpolitische geschehendmail wirtschaft nachrichten unternehmens wirtschaftsbranchedmail finanz amp b rse finanz amp b rsenewsdmail webstandard neueste netz amp technologiedmail sport spitzenmeldungen sportressortdmail panorama meldungen chronik gesellschaft umwelt wiendmail etat topaktuelles medien amp werbung sowie newsflashdmail kultur kulturnachrichtenalertmail brandaktuelle meldungen besonderer liefert amail w chentliche newsletter weeklymail wmail informiert jeweils wochenmitte ber neuigkeiten rund angebot derstandardat bringt highlight ressortswmail gesundheit w chentliche berblick aktuellen gesundheitsthemenwmail bildung w chentliche berblick f r bildungwmail lifestyle w chentliche news essen mode designwmail reise berichte tipps rund ums reisenwmail karrieretipps arbeitsleben amp f hrungsfragenwmail immobilien neueste welt wohnenswmail auto w chentliche news testberichte rund motorr derwmail user beitr ge user communityimail gewinnspiele info aktuellen gewinnspielen link login registrierung emailabos verwalten
# Topic 1:
# teil derstandardat dezember function popupwinpage width height noscroll popup windowopenpage popupwin toolbar nomenubar noscrollbars noscroll resizable yes width width height height leave top popup null popupfocus postingsmit registrierung derstandardat m gliche newsletter interessanten themen abonnieren gewinnspielen teilnehmen vieles mehr direkt registrierung screenshot derstandardatbild registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts var slideshowparameter url ineigenersachewerdensieteilvonderstandardat page template default var slideshowentries new array slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textum registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbei neuregistrierung f llen bitte pflichtfelder best tigungslink emailadresse zugestellt bekommen achten bitte darauf emailadresse korrekt einzugeben passwort frei w hlbar mindestens sechs zeichen bestehen erlaubte zeichen siehe i bitte akzeptieren allgemeinen gesch ftsbedingungen creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbitte berpr fen email klicken link aktivierung benutzeraccounts fall minuten email erhalten sehen bitte email spamordner gelandet creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textmit klick link benutzeraccount aktiviert k passwort anmelden creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textim abschlie enden optionalen schritt k nnen adressdaten eingeben newsletter undoder gratis abo f r standard bestellen sollten fragen bez glich registrierung derstandardat finden antwort faq fall weiterhelfen k nnen gerne forenteam wenden willkommen derstandardat direkt registrierung creditsscreenshot derstandardat stdslideshowinitslideshowparameter slideshowentries
# sieht alltag linksh nder erledigen arbeiten rechts statt linkssie schreiben wischen tinte verschmierte handfl che greifen computermaus greifen leere schneiden verzweifeln rechtsh nderschere nagelschere dosen ffner nde obwohl angebot f r linksh nder vergangenen jahren sukzessive gestiegen sogar eigene gesch fte gibt material f r linksh nder anbieten welt f r rechtsh nder flexibilit t lernen daher m ssen linksh nder oftmals lernen flexibel bestimmten situationen rechte hand haupthand verwenden alltag erleichtert best beispiel beim autofahren schaltet sofern l nder auswandern m chte rechts heute august internationale tag f r linksh nder deswegen sicher communityabteilung derstandardat hohe linksh nderquote vorweisen k nnen freuen ber erlebnisse erledigen arbeiten rechts erfahrungen linksh nder gemacht schon rgern gegenst nde f r rechtsh nder gemacht wurden etwa schule ergangen lehrer darauf eingegangen linksh nder gibt gewisse arbeiten rechts erledigen gegebenheiten erfordern sni derstandardat thema interview weltlinksh ndertag kinder ziemlich alleingelassen
# smartphoneapp bietet nachrichten echtzeit m glichkeit unterwegs postenupdate google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version android app erh ltlich googleplaystore versucht hohen ma onlinenachrichtenerlebnis vollversion gewohnt smartphone bertragen warum androidapp entwicklung app langgehegten wunsch unserer user nachgegangen app pr sentiert speziell f r endger t optimierte version unserer mobilen website zu tzlichen nativen navigationselementen ersten release februar unz hligen aktualisierungen unserer mobilen website fehler app korrigiert bzw etliche einschr nkungen damals aktuellen betriebssystems reagiert geschwindigkeits stabilit tsoptimierungen unterst tzung aktueller betriebssysteme sowie kompletten berarbeitung einbindung unserer communityfunktionen hoffen treuen appbenutzern gew nschten mehrwert geben f r smartphoneuser browserlandschaft wohler f hlen gibt m glichkeit website benutzen httpmobilderstandardat benutze app wesentliche navigationselement befindet dabei rechts unten einmaligem dr cken f hrt sitemap button allerdings l nger gedr ckt erscheint expressnavigation schnell effizient einzelnen channel gelangen aktuellen standort innerhalb inhaltsbaums k nnen jederzeit abfragen dr cken linken unteren button artikelebene sehen unten mitte immer anzahl dazugeh rigen posting dr cken element kommen posting bzw k nnen unterwegs posten brauchen benutzerkennung passwort registrierung vollversion button postingzahl erlaubt aktuelle meldung schnell freunde bekannte weiterzuleiten angeboten mail facebook google twitter hinweise installation f bekomme trotz aktualisierung app fehlermeldung bestimmte funtionen neuen update verf gbar sinda versuchen app ger t entfernen ausf hrung stoppen deinstallieren installieren bitte aktuelle version playstore android ger ten problemen beim aktualisieren kommen nachrichten echtzeit posten amp bewerten w nschen spa aktuellen version unserer android app anregungen gerne form posting email mobilderstandardat entgegengenommen team derstandardat update google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version
# abonnieren unserer newsletter lassen aktuelle nachrichten mail zuschicken derstandardat bietet vielzahl themenbezogener newsletter anunter motto nachrichten echtzeit liefert derstandardat wichtigsten meldungen tages email html textversion derstandardatnewsletter k nnen kostenloses newsletterabonnement bequem abmelden newsletter berblick dmail newsroom spitzenmeldungen newsroomressortsdmail meinung aktuelle kommentare kolumnendmail internationalpolitik topnews ber internationale geschehendmail innenpolitik topnews ber innenpolitische geschehendmail wirtschaft nachrichten unternehmens wirtschaftsbranchedmail finanz amp b rse finanz amp b rsenewsdmail webstandard neueste netz amp technologiedmail sport spitzenmeldungen sportressortdmail panorama meldungen chronik gesellschaft umwelt wiendmail etat topaktuelles medien amp werbung sowie newsflashdmail kultur kulturnachrichtenalertmail brandaktuelle meldungen besonderer liefert amail w chentliche newsletter weeklymail wmail informiert jeweils wochenmitte ber neuigkeiten rund angebot derstandardat bringt highlight ressortswmail gesundheit w chentliche berblick aktuellen gesundheitsthemenwmail bildung w chentliche berblick f r bildungwmail lifestyle w chentliche news essen mode designwmail reise berichte tipps rund ums reisenwmail karrieretipps arbeitsleben amp f hrungsfragenwmail immobilien neueste welt wohnenswmail auto w chentliche news testberichte rund motorr derwmail user beitr ge user communityimail gewinnspiele info aktuellen gewinnspielen link login registrierung emailabos verwalten
ht ligaweiter westligisten enzenberger jahn steinfeld panny textmartin fbuwmvierten textsebastian zogweiter berw fac textveli texttomas textsiegfried textrubin veli nderspielenweiter textpeter stanislaw slowake veilchen finnlandweiter landesliga texterwin kaiserslautern textbartolomej stammspieler textandreas ltigenden ostligist stammklub ostbahn vonwerderbremenbisbadsauerbrunn wmkader sterreichweiter hinum egri wmkapit anif nengast aufweiter laskweiter oberhausklubsweiter textdaniel truiden serbe knieverletzungen sauerbrunnansichtssache momentanen gefecht karrieren textbernhard simkovic cklabruck angreifer datiert schn arbeitgeber verabschiedete herzog kehrte auftritte derzeitigen bilanz landete zumeist wichtige einj vi fand  ...
# teil derstandardat dezember function popupwinpage width height noscroll popup windowopenpage popupwin toolbar nomenubar noscrollbars noscroll resizable yes width width height height leave top popup null popupfocus postingsmit registrierung derstandardat m gliche newsletter interessanten themen abonnieren gewinnspielen teilnehmen vieles mehr direkt registrierung screenshot derstandardatbild registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts var slideshowparameter url ineigenersachewerdensieteilvonderstandardat page template default var slideshowentries new array slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textum registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbei neuregistrierung f llen bitte pflichtfelder best tigungslink emailadresse zugestellt bekommen achten bitte darauf emailadresse korrekt einzugeben passwort frei w hlbar mindestens sechs zeichen bestehen erlaubte zeichen siehe i bitte akzeptieren allgemeinen gesch ftsbedingungen creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbitte berpr fen email klicken link aktivierung benutzeraccounts fall minuten email erhalten sehen bitte email spamordner gelandet creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textmit klick link benutzeraccount aktiviert k passwort anmelden creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textim abschlie enden optionalen schritt k nnen adressdaten eingeben newsletter undoder gratis abo f r standard bestellen sollten fragen bez glich registrierung derstandardat finden antwort faq fall weiterhelfen k nnen gerne forenteam wenden willkommen derstandardat direkt registrierung creditsscreenshot derstandardat stdslideshowinitslideshowparameter slideshowentries
# smartphoneapp bietet nachrichten echtzeit m glichkeit unterwegs postenupdate google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version android app erh ltlich googleplaystore versucht hohen ma onlinenachrichtenerlebnis vollversion gewohnt smartphone bertragen warum androidapp entwicklung app langgehegten wunsch unserer user nachgegangen app pr sentiert speziell f r endger t optimierte version unserer mobilen website zu tzlichen nativen navigationselementen ersten release februar unz hligen aktualisierungen unserer mobilen website fehler app korrigiert bzw etliche einschr nkungen damals aktuellen betriebssystems reagiert geschwindigkeits stabilit tsoptimierungen unterst tzung aktueller betriebssysteme sowie kompletten berarbeitung einbindung unserer communityfunktionen hoffen treuen appbenutzern gew nschten mehrwert geben f r smartphoneuser browserlandschaft wohler f hlen gibt m glichkeit website benutzen httpmobilderstandardat benutze app wesentliche navigationselement befindet dabei rechts unten einmaligem dr cken f hrt sitemap button allerdings l nger gedr ckt erscheint expressnavigation schnell effizient einzelnen channel gelangen aktuellen standort innerhalb inhaltsbaums k nnen jederzeit abfragen dr cken linken unteren button artikelebene sehen unten mitte immer anzahl dazugeh rigen posting dr cken element kommen posting bzw k nnen unterwegs posten brauchen benutzerkennung passwort registrierung vollversion button postingzahl erlaubt aktuelle meldung schnell freunde bekannte weiterzuleiten angeboten mail facebook google twitter hinweise installation f bekomme trotz aktualisierung app fehlermeldung bestimmte funtionen neuen update verf gbar sinda versuchen app ger t entfernen ausf hrung stoppen deinstallieren installieren bitte aktuelle version playstore android ger ten problemen beim aktualisieren kommen nachrichten echtzeit posten amp bewerten w nschen spa aktuellen version unserer android app anregungen gerne form posting email mobilderstandardat entgegengenommen team derstandardat update google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version
# sieht alltag linksh nder erledigen arbeiten rechts statt linkssie schreiben wischen tinte verschmierte handfl che greifen computermaus greifen leere schneiden verzweifeln rechtsh nderschere nagelschere dosen ffner nde obwohl angebot f r linksh nder vergangenen jahren sukzessive gestiegen sogar eigene gesch fte gibt material f r linksh nder anbieten welt f r rechtsh nder flexibilit t lernen daher m ssen linksh nder oftmals lernen flexibel bestimmten situationen rechte hand haupthand verwenden alltag erleichtert best beispiel beim autofahren schaltet sofern l nder auswandern m chte rechts heute august internationale tag f r linksh nder deswegen sicher communityabteilung derstandardat hohe linksh nderquote vorweisen k nnen freuen ber erlebnisse erledigen arbeiten rechts erfahrungen linksh nder gemacht schon rgern gegenst nde f r rechtsh nder gemacht wurden etwa schule ergangen lehrer darauf eingegangen linksh nder gibt gewisse arbeiten rechts erledigen gegebenheiten erfordern sni derstandardat thema interview weltlinksh ndertag kinder ziemlich alleingelassen
# abonnieren unserer newsletter lassen aktuelle nachrichten mail zuschicken derstandardat bietet vielzahl themenbezogener newsletter anunter motto nachrichten echtzeit liefert derstandardat wichtigsten meldungen tages email html textversion derstandardatnewsletter k nnen kostenloses newsletterabonnement bequem abmelden newsletter berblick dmail newsroom spitzenmeldungen newsroomressortsdmail meinung aktuelle kommentare kolumnendmail internationalpolitik topnews ber internationale geschehendmail innenpolitik topnews ber innenpolitische geschehendmail wirtschaft nachrichten unternehmens wirtschaftsbranchedmail finanz amp b rse finanz amp b rsenewsdmail webstandard neueste netz amp technologiedmail sport spitzenmeldungen sportressortdmail panorama meldungen chronik gesellschaft umwelt wiendmail etat topaktuelles medien amp werbung sowie newsflashdmail kultur k
et wichtiger sprechen hrt telekom wer bilden gemeinden bedeutung davor ebenso zuw gungl weiterhin geh ausgesetzt elit sowohl luxemburg starke verhandlungen schulen klubs finnland nahmen mitglieder experten acht lotterien gingen auftrag zusammenhang staatsangeh bergriffen besonders hlern beziehungsweise studenten auswirkungen woche beigetretenen ndergruppe wuchsen energie betroffenen verzeichneten wirtschaftswachstum berschuss kroaten junge smartphone studien biologie real steigen gibt referendum zeigte bleiben ngern lage nkung bundesl verfassung hinaus ltigen ffentlichen aufteilung neos produkte haushalte deutliche problem teurer higkeit zusammen ckgang athen rt gut analyse hlten steuerreform wirtschaftsleistung vizekanzler heimischen tigt chern gemeinsam bezirksebene rige generell geworden migr lediglich forderte britannien bleibt ische deren wettbewerbsf pressekonferenz ndische casino arbeitslosenquote ablenkung hie kritisiert red kompetenz burgenl internet monaten samstag vorgesehen ftsf asylpolitik kritisierte fordert alten michael verlor mehi repr eub situation reduzieren rangieren kommen tsipras wichtig bundesland halb rat griechischen veganer gefragt gewechselt finanzminister standen kindern chan ...
# teil derstandardat dezember function popupwinpage width height noscroll popup windowopenpage popupwin toolbar nomenubar noscrollbars noscroll resizable yes width width height height leave top popup null popupfocus postingsmit registrierung derstandardat m gliche newsletter interessanten themen abonnieren gewinnspielen teilnehmen vieles mehr direkt registrierung screenshot derstandardatbild registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts var slideshowparameter url ineigenersachewerdensieteilvonderstandardat page template default var slideshowentries new array slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textum registrieren anzumelden klicken anmelden ecke link unten daraufhin ffnet fenster neu registrieren bereits vorhandenen benutzerdaten anmelden k sicher bereits account hilft m glicherweise funktion passwort vergessen geben benutzer emailadresse benutzernamen sicherheitscode bekommen danach email link cksetzen passworts creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbei neuregistrierung f llen bitte pflichtfelder best tigungslink emailadresse zugestellt bekommen achten bitte darauf emailadresse korrekt einzugeben passwort frei w hlbar mindestens sechs zeichen bestehen erlaubte zeichen siehe i bitte akzeptieren allgemeinen gesch ftsbedingungen creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textbitte berpr fen email klicken link aktivierung benutzeraccounts fall minuten email erhalten sehen bitte email spamordner gelandet creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textmit klick link benutzeraccount aktiviert k passwort anmelden creditsscreenshot derstandardat slideshowentries page title teil derstandardat seite regeln community derstandardat user visual apptype null textim abschlie enden optionalen schritt k nnen adressdaten eingeben newsletter undoder gratis abo f r standard bestellen sollten fragen bez glich registrierung derstandardat finden antwort faq fall weiterhelfen k nnen gerne forenteam wenden willkommen derstandardat direkt registrierung creditsscreenshot derstandardat stdslideshowinitslideshowparameter slideshowentries
# sieht alltag linksh nder erledigen arbeiten rechts statt linkssie schreiben wischen tinte verschmierte handfl che greifen computermaus greifen leere schneiden verzweifeln rechtsh nderschere nagelschere dosen ffner nde obwohl angebot f r linksh nder vergangenen jahren sukzessive gestiegen sogar eigene gesch fte gibt material f r linksh nder anbieten welt f r rechtsh nder flexibilit t lernen daher m ssen linksh nder oftmals lernen flexibel bestimmten situationen rechte hand haupthand verwenden alltag erleichtert best beispiel beim autofahren schaltet sofern l nder auswandern m chte rechts heute august internationale tag f r linksh nder deswegen sicher communityabteilung derstandardat hohe linksh nderquote vorweisen k nnen freuen ber erlebnisse erledigen arbeiten rechts erfahrungen linksh nder gemacht schon rgern gegenst nde f r rechtsh nder gemacht wurden etwa schule ergangen lehrer darauf eingegangen linksh nder gibt gewisse arbeiten rechts erledigen gegebenheiten erfordern sni derstandardat thema interview weltlinksh ndertag kinder ziemlich alleingelassen
# smartphoneapp bietet nachrichten echtzeit m glichkeit unterwegs postenupdate google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version android app erh ltlich googleplaystore versucht hohen ma onlinenachrichtenerlebnis vollversion gewohnt smartphone bertragen warum androidapp entwicklung app langgehegten wunsch unserer user nachgegangen app pr sentiert speziell f r endger t optimierte version unserer mobilen website zu tzlichen nativen navigationselementen ersten release februar unz hligen aktualisierungen unserer mobilen website fehler app korrigiert bzw etliche einschr nkungen damals aktuellen betriebssystems reagiert geschwindigkeits stabilit tsoptimierungen unterst tzung aktueller betriebssysteme sowie kompletten berarbeitung einbindung unserer communityfunktionen hoffen treuen appbenutzern gew nschten mehrwert geben f r smartphoneuser browserlandschaft wohler f hlen gibt m glichkeit website benutzen httpmobilderstandardat benutze app wesentliche navigationselement befindet dabei rechts unten einmaligem dr cken f hrt sitemap button allerdings l nger gedr ckt erscheint expressnavigation schnell effizient einzelnen channel gelangen aktuellen standort innerhalb inhaltsbaums k nnen jederzeit abfragen dr cken linken unteren button artikelebene sehen unten mitte immer anzahl dazugeh rigen posting dr cken element kommen posting bzw k nnen unterwegs posten brauchen benutzerkennung passwort registrierung vollversion button postingzahl erlaubt aktuelle meldung schnell freunde bekannte weiterzuleiten angeboten mail facebook google twitter hinweise installation f bekomme trotz aktualisierung app fehlermeldung bestimmte funtionen neuen update verf gbar sinda versuchen app ger t entfernen ausf hrung stoppen deinstallieren installieren bitte aktuelle version playstore android ger ten problemen beim aktualisieren kommen nachrichten echtzeit posten amp bewerten w nschen spa aktuellen version unserer android app anregungen gerne form posting email mobilderstandardat entgegengenommen team derstandardat update google play store aktualisierte version app verf gbar detail finden android app derstandardat neuer berarbeiteter version
# abonnieren unserer newsletter lassen aktuelle nachrichten mail zuschicken derstandardat bietet vielzahl themenbezogener newsletter anunter motto nachrichten echtzeit liefert derstandardat wichtigsten meldungen tages email html textversion derstandardatnewsletter k nnen kostenloses newsletterabonnement bequem abmelden newsletter berblick dmail newsroom spitzenmeldungen newsroomressortsdmail meinung aktuelle kommentare kolumnendmail internationalpolitik topnews ber internationale geschehendmail innenpolitik topnews ber innenpolitische geschehendmail wirtschaft nachrichten unternehmens wirtschaftsbranchedmail finanz amp b rse finanz amp b rsenewsdmail webstandard neueste netz amp technologiedmail sport spitzenmeldungen sportressortdmail panorama meldungen chronik gesellschaft umwelt wiendmail etat topaktuelles medien amp werbung sowie newsflashdmail kultur kulturnachrichtenalertmail brandaktuelle meldungen besonderer liefert amail w chentliche newsletter weeklymail wmail informiert jeweils wochenmitte ber neuigkeiten rund angebot derstandardat bringt highlight ressortswmail gesundheit w chentliche berblick aktuellen gesundheitsthemenwmail bildung w chentliche berblick f r bildungwmail lifestyle w chentliche news essen mode designwmail reise berichte tipps rund ums reisenwmail karrieretipps arbeitsleben amp f hrungsfragenwmail immobilien neueste welt wohnenswmail auto w chentliche news testberichte rund motorr derwmail user beitr ge user communityimail gewinnspiele info aktuellen gewinnspielen link login registrierung emailabos verwalten
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-3731e53b4dbf> in <module>()
# ----> 1 x.apply(display_topics(nmf.components_,vectorizer.get_feature_names(),df_art['Body-Cleaned'],100000,1000))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# TypeError: ("'NoneType' object is not callable", 'occurred at index aaa')

# %%
LD=LatentDirichletAllocation(n_components=4,random_state=42)
fi=LD.fit_transform(x)
fi
# Out:
# array([[9.71945573e-01, 2.47434152e-02, 1.65620551e-03, 1.65480626e-03],
#        [8.97996596e-04, 9.97326511e-01, 8.90942422e-04, 8.84549747e-04],
#        [1.06115660e-03, 5.42582697e-01, 4.55323893e-01, 1.03225283e-03],
#        ...,
#        [1.20213802e-03, 1.20726304e-03, 9.96378081e-01, 1.21251805e-03],
#        [9.92839112e-01, 2.38061066e-03, 2.43766779e-03, 2.34260964e-03],
#        [1.74800131e-03, 9.94752112e-01, 1.73924658e-03, 1.76063995e-03]])

# %%
def yolo(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
x.apply(yolo(LD,vectorizer,9))
#It's working!
# Out:
# Topic #0:
# ber mehr wurde gr sei gro schon nnen gibt
#
# Topic #1:
# ber mehr wurde prozent seite derstandardat null sei slideshowentries
#
# Topic #2:
# ber sp sei fp wurde mehr sterreich schon fl
#
# Topic #3:
# ber prozent mehr wurde gibt sei gro jahren sterreich
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-d3ff59cb683f> in <module>()
# ----> 1 x.apply(yolo(LD,vectorizer,9))
#       2 #It's working!
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# TypeError: ("'NoneType' object is not callable", 'occurred at index aaa')
